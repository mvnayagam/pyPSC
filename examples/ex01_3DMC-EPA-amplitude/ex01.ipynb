# %% [markdown]
# # <font color = 'blue'> Ex01: 3DMC
# ``EPA - Amplitude approach``

# %% [markdown]
# ## <font color = 'green'> **Importing modules**

# %%
# %matplotlib widget

import warnings
warnings.filterwarnings('ignore')

import os
import numpy as np
import polytope as pc
from itertools import product

import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d.art3d import Poly3DCollection


from psc.g_space import g
from psc.x3Dlinearizazion import linearnD_EPA
from psc.x3Drepetition import getmesh, getsigncom, getpolytope_EPA
from psc.x3Dchecklinearization import checklinear
from psc.x3Dintersection import find_intersection
from psc.x3Dplot import plot_polytope
from psc.x3Dreadwrite import wrtdata

# %% [markdown]
# ## <font color = 'green'> **Running MC simulation in 3D PS**

# %%
from psc.nDMC_EPA import nDMC_EPA

nDMC_EPA(dimension=3, noofpair=5, noofRO=9, iorg='amplitude', imax=0.5)

# %% [markdown]
# ## <font color = 'green'> **Plotting MC simulation results**
#     1. To understand the meaning of the plot, see the manuscript

# %%
from psc.utils.plot3DMC_results import plot3dmcresults
h = 9
fpath = os.path.join(os.getcwd(), 'psc\\examples\\ex01')

plot3dmcresults(h, fpath)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## <font color = 'green'> **Plotting MC simulation time consumption**
#     1. To understand the meaning of the plot, see the manuscript
#     2. Refer what is Box plot in python

# %%
from psc.utils.plottime  import plottime_nD

fpath = os.path.join(os.getcwd(), 'psc\\examples\\ex01')
h = 9 ; 
plottime_nD(fpath, h, interval=1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
