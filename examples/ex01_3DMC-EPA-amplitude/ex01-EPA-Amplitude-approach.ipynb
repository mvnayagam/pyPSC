# %% [markdown]
# # <font color = 'blue'> Ex01: 3DMC
# ``EPA - Amplitude approach``

# %% [markdown]
# ## <font color = 'green'> **Importing modules**

# %%
# %matplotlib widget

import warnings
warnings.filterwarnings('ignore')

import os
import numpy as np

from psc.tools.xplottotaltime import plottotaltime
from psc.tools.plot3DMCresults import plot3dmcresults
from psc.lib.nDMC_EPA import nDMC_EPA

# %% [markdown]
# ## <font color = 'green'> **Running MC simulation in 3D PS**

# %%
# ---> call nDMC_EPA to solve a structure. 
# ---> Must be specified variables: dimension (must be >=3), number of structures you
#      want to test and number of reflection to be taken into account.

# ------------------> WARNUNG <--------------------------------------------------------
# dimension must be 3 or higher. for dimension=2 we have another routine to call

nDMC_EPA(dimension=3, noofpair=1, structure=[], noofRO=9, iorg='amplitude', restart=False, restarth=5, restartpath='./', imax=0.5)
# Out:
# ---> I find noofpair variable to be true. I will create 1 pairs
# ---> Generated pairs are:
#  [[0.11055 0.13786 0.4075 ]]
# ===> Dir results is created. Output files will be saved to  C:\Users\pearl\Desktop\MCresult-2024-09-17-003432  location
#
#
#
# =====> for h =  2 ==============================
#
# ===> Pair- 1:  Current pair:  [0.11055 0.13786 0.4075 ] Solving for:  [0.4075  0.13786 0.11055]
# start: 00:34:32 --> Polytope contains complete isosurface. Successful Linearization for RO = 1
# --> Polytope contains complete isosurface. Successful Linearization for RO = 2
# iso: 00:34:32 poly: 00:34:32 intersection: 00:34:32 sort sol: 00:34:32 contains_coordinates: [ True False]
# in try inx : [0] len(inx) 1 best_inx: 0
#  -> L(s): 2 s: 0 <- wrt: 00:34:32  Total: 0:00:00.342584
# ---> predicted struc:[0.05205 0.18778 0.40393]. Given struc: [0.11055 0.13786 0.4075 ]
#
#  intermediate total: 0:00:00.388205
#
# =====> for h =  3 ==============================
#
# ...

# %% [markdown]
# ## <font color = 'green'> **Plotting MC simulation results**
#     1. To understand the meaning of the plot, see the manuscript

# %%
# ---> Routine starts to plot

h = 9

# ---> NOTE: change the folder name according to your calculation

folder='MCresult-2024-09-17-003432'
fpath  = os.path.join(os.path.join(os.environ['USERPROFILE']), 'Desktop', folder) 

# ---> Routine starts to plot
plot3dmcresults(h, fpath)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## <font color = 'green'> **Plotting MC simulation time consumption**
#     1. To understand the meaning of the plot, see the manuscript
#     2. Refer what is Box plot in python

# %%
# ---> NOTE: change the reflection according to your calculation
h = 9; hl=np.arange(2, h)

# ---> NOTE: change the folder name according to your calculation
folder='MCresult-2024-09-17-003432'

# ---> Routine starts to plot
fpath  = os.path.join(os.path.join(os.environ['USERPROFILE']), 'Desktop', folder) 

plottotaltime(hl, fpath)
# Out:
# ---> I am reading files from the path :: C:\Users\pearl\Desktop\MCresult-2024-09-17-003432
# ---> fn : C:\Users\pearl\Desktop\MCresult-2024-09-17-003432\pnew_2.h5
# ---> fn : C:\Users\pearl\Desktop\MCresult-2024-09-17-003432\pnew_3.h5
# ---> fn : C:\Users\pearl\Desktop\MCresult-2024-09-17-003432\pnew_4.h5
# ---> fn : C:\Users\pearl\Desktop\MCresult-2024-09-17-003432\pnew_5.h5
# ---> fn : C:\Users\pearl\Desktop\MCresult-2024-09-17-003432\pnew_6.h5
# ---> fn : C:\Users\pearl\Desktop\MCresult-2024-09-17-003432\pnew_7.h5
# ---> fn : C:\Users\pearl\Desktop\MCresult-2024-09-17-003432\pnew_8.h5
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
